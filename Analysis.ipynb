# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('C:\\project_final\\final_project\\result.csv')

# %% [markdown]
# ## Stock BYND on 5/14/2020 Hourly High Price Plot

# %%
bynd = df['ticket_name']=='BYND'
bynd_df = df[bynd]
bynd_df.plot(x='hour',y='hourly_high_price')

# %% [markdown]
# ## Stock BYND Histogram and KDE

# %%
bynd_df['hourly_high_price'].plot(kind='hist',legend='True')
bynd_df['hourly_high_price'].plot(kind='kde')

# %%
sns.distplot(bynd_df['hourly_high_price'],bins=5,color='purple')
